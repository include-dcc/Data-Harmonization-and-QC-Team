# %% [markdown]
# # Extract ICD10 terms to map
#
# The goal of this notebook is to create a file of ICD10CM terms that contains _only_ the codes from the DS-Determined data where an existing ICD10 mapping did not exist on a Mondo term. The result of the initial mapping of the ICD codes to Mondo is at: https://www.synapse.org/Synapse:syn63923531

# %%
# Imports

import pandas as pd

pd.set_option('display.max_colwidth', None)

# %%
# Read file of all ICD10 terms extracted using a SPARQL query as described in the README in this folder.

icd10_df = pd.read_csv('../data/icd10_labels.tsv', sep='\t')
display(icd10_df.head())
# Out:
#             ?curie                                               ?label  \
# 0      ICD10CM:A00                                              Cholera
# 1  ICD10CM:A00-A09             Intestinal infectious diseases (A00-A09)
# 2  ICD10CM:A00-A09             Intestinal infectious diseases (A00-A09)
# 3  ICD10CM:A00-B99  Certain infectious and parasitic diseases (A00-B99)
# 4  ICD10CM:A00-B99  Certain infectious and parasitic diseases (A00-B99)
#
#    ?definition                                             ?synonym
# 0          NaN                                              Cholera
# 1          NaN             Intestinal infectious diseases (A00-A09)
# 2          NaN                       intestinal infectious diseases
# 3          NaN  Certain infectious and parasitic diseases (A00-B99)
# 4          NaN            certain infectious and parasitic diseases

# %%
# Read file of DS-Determined ICD10 codes

dsd_icd10_df = pd.read_csv('../data/ds-determined-icd10_icd-mondo_mappings.tsv', sep='\t')

display(dsd_icd10_df.head())
display(dsd_icd10_df.nunique())
# Out:
#          icd_code  icd_version    mondo_curie  \
# 0   ICD10CM:G93.2           10            NaN
# 1  ICD10CM:I31.39           10            NaN
# 2  ICD10CM:M08.90           10            NaN
# 3  ICD10CM:F63.81           10  MONDO:0001521
# 4  ICD10CM:F02.80           10            NaN
#
#                        mondo_label      mondo_xref mondo_is_obsolete  \
# 0                              NaN             NaN               NaN
# 1                              NaN             NaN               NaN
# 2                              NaN             NaN               NaN
# 3  intermittent explosive disorder  ICD10CM:F63.81             False
# 4                              NaN             NaN               NaN
#
#   mondo_has_equivalentTo
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                   True
# 4                    NaN
# icd_code                  1701
# icd_version                  1
# mondo_curie                114
# mondo_label                114
# mondo_xref                  64
# mondo_is_obsolete            2
# mondo_has_equivalentTo       2
# dtype: int64

# %%
# Filter DS-Determined ICD-Mondo mapping dataframe to only rows with no value for `mondo_curie`

filtered_dsd_icd10_df = dsd_icd10_df[dsd_icd10_df['mondo_curie'].isna()]

display(filtered_dsd_icd10_df.head())
display(filtered_dsd_icd10_df.nunique())
# Out:
#          icd_code  icd_version mondo_curie mondo_label mondo_xref  \
# 0   ICD10CM:G93.2           10         NaN         NaN        NaN
# 1  ICD10CM:I31.39           10         NaN         NaN        NaN
# 2  ICD10CM:M08.90           10         NaN         NaN        NaN
# 4  ICD10CM:F02.80           10         NaN         NaN        NaN
# 6   ICD10CM:Q21.0           10         NaN         NaN        NaN
#
#   mondo_is_obsolete mondo_has_equivalentTo
# 0               NaN                    NaN
# 1               NaN                    NaN
# 2               NaN                    NaN
# 4               NaN                    NaN
# 6               NaN                    NaN
# icd_code                  1637
# icd_version                  1
# mondo_curie                  0
# mondo_label                  0
# mondo_xref                   0
# mondo_is_obsolete            0
# mondo_has_equivalentTo       0
# dtype: int64

# %%
# Join `filtered_dsd_icd10_df` to `icd10_df` to get the term labels and other annotations for these codes from DS-Determined
# that do not have an existing Mondo database cross-reference to ICD10

combined_df = filtered_dsd_icd10_df.merge(icd10_df, left_on='icd_code', right_on='?curie', how='left')

display(combined_df.head())
display(combined_df.nunique())
# Out:
#          icd_code  icd_version mondo_curie mondo_label mondo_xref  \
# 0   ICD10CM:G93.2           10         NaN         NaN        NaN
# 1   ICD10CM:G93.2           10         NaN         NaN        NaN
# 2  ICD10CM:I31.39           10         NaN         NaN        NaN
# 3  ICD10CM:M08.90           10         NaN         NaN        NaN
# 4  ICD10CM:F02.80           10         NaN         NaN        NaN
#
#   mondo_is_obsolete mondo_has_equivalentTo          ?curie  \
# 0               NaN                    NaN   ICD10CM:G93.2
# 1               NaN                    NaN   ICD10CM:G93.2
# 2               NaN                    NaN             NaN
# 3               NaN                    NaN  ICD10CM:M08.90
# 4               NaN                    NaN  ICD10CM:F02.80
#
#                                                                            ?label  \
# 0                                                Benign intracranial hypertension
# 1                                                Benign intracranial hypertension
# 2                                                                             NaN
# 3                               Juvenile arthritis, unspecified, unspecified site
# 4  Dementia in other diseases classified elsewhere without behavioral disturbance
#
#    ?definition                                             ?synonym
# 0          NaN                     Benign intracranial hypertension
# 1          NaN                                          Pseudotumor
# 2          NaN                                                  NaN
# 3          NaN    Juvenile arthritis, unspecified, unspecified site
# 4          NaN  Dementia in other diseases classified elsewhere NOS
# icd_code                  1637
# icd_version                  1
# mondo_curie                  0
# mondo_label                  0
# mondo_xref                   0
# mondo_is_obsolete            0
# mondo_has_equivalentTo       0
# ?curie                    1583
# ?label                    1579
# ?definition                  0
# ?synonym                  2819
# dtype: int64

# %%
# Let's only keep columns of interest

cols_to_keep = [
    "icd_code",
    "?label",
    "?definition",
    "?synonym"
]

filtered_combined_df = combined_df[cols_to_keep]

display(filtered_combined_df.head())
display(filtered_combined_df.nunique())
# Out:
#          icd_code  \
# 0   ICD10CM:G93.2
# 1   ICD10CM:G93.2
# 2  ICD10CM:I31.39
# 3  ICD10CM:M08.90
# 4  ICD10CM:F02.80
#
#                                                                            ?label  \
# 0                                                Benign intracranial hypertension
# 1                                                Benign intracranial hypertension
# 2                                                                             NaN
# 3                               Juvenile arthritis, unspecified, unspecified site
# 4  Dementia in other diseases classified elsewhere without behavioral disturbance
#
#    ?definition                                             ?synonym
# 0          NaN                     Benign intracranial hypertension
# 1          NaN                                          Pseudotumor
# 2          NaN                                                  NaN
# 3          NaN    Juvenile arthritis, unspecified, unspecified site
# 4          NaN  Dementia in other diseases classified elsewhere NOS
# icd_code       1637
# ?label         1579
# ?definition       0
# ?synonym       2819
# dtype: int64

# %%
# Group by synonyms to have rows for only unique codes and labels

# Group and join unique synonyms as a string
grouped_filtered_combined_df = filtered_combined_df.groupby('icd_code')['?synonym'] \
    .apply(lambda x: ', '.join(sorted(set(x.dropna().astype(str))))) \
    .reset_index(name='grouped_synonym')

# Drop duplicates based on icd_code and keep the first row
deduped_df = filtered_combined_df.drop_duplicates(subset='icd_code', keep='first')

# Merge grouped synonyms into the deduplicated DataFrame
final_df = deduped_df.merge(grouped_filtered_combined_df, on='icd_code', how='left')

# Rename columns
final_df = final_df.rename(columns={
    '?label': 'label',
    '?definition': 'definition',
    '?synonym': 'synonym'
})

display(final_df.head())
display(final_df.nunique())
# Out:
#          icd_code  \
# 0   ICD10CM:G93.2
# 1  ICD10CM:I31.39
# 2  ICD10CM:M08.90
# 3  ICD10CM:F02.80
# 4   ICD10CM:Q21.0
#
#                                                                             label  \
# 0                                                Benign intracranial hypertension
# 1                                                                             NaN
# 2                               Juvenile arthritis, unspecified, unspecified site
# 3  Dementia in other diseases classified elsewhere without behavioral disturbance
# 4                                                       Ventricular septal defect
#
#    definition                                              synonym  \
# 0         NaN                     Benign intracranial hypertension
# 1         NaN                                                  NaN
# 2         NaN    Juvenile arthritis, unspecified, unspecified site
# 3         NaN  Dementia in other diseases classified elsewhere NOS
# 4         NaN                                      Roger's disease
#
#                                                                                                                                                                                              grouped_synonym
# 0                                                                                                                                                              Benign intracranial hypertension, Pseudotumor
# 1
# 2                                                                                                                                                          Juvenile arthritis, unspecified, unspecified site
# 3  Dementia in other diseases classified elsewhere NOS, Dementia in other diseases classified elsewhere without behavioral disturbance, Major neurocognitive disorder in other diseases classified elsewhere
# 4                                                                                                                                                                 Roger's disease, Ventricular septal defect
# icd_code           1637
# label              1579
# definition            0
# synonym            1580
# grouped_synonym    1584
# dtype: int64

# %%
# Save to file
final_df.to_csv('icd10_code_to_map.tsv', sep='\t', index=False)
